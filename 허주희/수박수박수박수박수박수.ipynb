# %%
def solution(n):
    answer = ""
    
    if n%2 == 0:
        for _ in range(0, n//2):
            print("수박", end= "")
    else :
        for _ in range(0, n//2):
            print("수박", end="")
        print("수")
    return answer

n = 7
print(solution(n))
# Out:
# 수박수박수박수

# %% [markdown]
# ![image.png](attachment:image.png)
