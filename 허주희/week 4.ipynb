# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # * dict_ = defaultdic(defaultdict)

# %% [markdown]
# https://www.daleseo.com/python-collections-defaultdict/

# %% [markdown]
# # * zip 함수

# %% [markdown]
# ![image.png](attachment:image.png)
