# %% [markdown]
# ## 12-33: 전화 번호 문자 조합

# %% [markdown]
# - 2에서 9까지 숫자가 주어졌을 때 전화 번호로 조합 가능한 모든 문자를 출력하라.

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# - 입력:
#
# ~~~
# "23"
# ~~~
#
# - 출력:
#
# ~~~
# ["ad", "ae", "af", "bd", "be", "bf", "cd", "ce", "cf"]
# ~~~

# %% [markdown]
# - 설명: 2는 abc, 3은 def가 가능하므로 각각 한 문자씩 9개의 문자로 조합 가능하다.

# %% [markdown]
# ### 풀이: 모든 조합 탐색
#
# - 부분만 보고 어떻게 해볼 수 있지 않을까?: 안됨!
#
# - for문을 쓰면 되지 않을까?
#
# - 근데 for문을 쓰면 입력 숫자가 하나 늘어날때마다 for문 하나씩 추가해야됨 $→$ 비효율적

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
from typing import List
from collections import defaultdict
    
def letterCombinations(digits: str) -> List[str]:
  def dfs(index, path):
      # 끝까지 탐색하면 백트래킹
      if len(path) == len(digits):
          result.append(path)
          return

      # 입력값 자릿수 단위 반복
      for i in range(index, len(digits)):
          # 숫자에 해당하는 모든 문자열 반복
          for j in dic[digits[i]]:
              dfs(i + 1, path + j)

  """
  # digits: 입력
  # dic: 키판 배열
  """
  # 예외 처리: 비어있으면 빈 리스트 리턴
  if not digits:
      return []

  dic = {"2": "abc", "3": "def", "4": "ghi", "5": "jkl",
          "6": "mno", "7": "pqrs", "8": "tuv", "9": "wxyz"}
  result = [] # 결과값 
  dfs(0, "")

  return result

# result = ["ad", "ae", "af", "bd", "be", "bf", "cd", "ce", "cf"]
input = "23"

print(letterCombinations(input))
# Out:
# ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
